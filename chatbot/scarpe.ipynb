# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://cgwb.gov.in/cgwbpnm/")
docs = []
for doc in loader.lazy_load():
    docs.append(doc)
print(docs)
# Out:
# [Document(metadata={'source': 'https://cgwb.gov.in/cgwbpnm/', 'title': 'CGWB - Publications and Media Warehouse', 'language': 'en'}, page_content='\n\n\n\n\n\n\nCGWB - Publications and Media Warehouse\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCentral Ground Water Board (CGWB)Ministry of Jal Shakti, Department of Water Resources, River \nDevelopment and Ganga RejuvenationGovernment of India\n\n\n\n\n\n\n\n  \n\n\n Home \n Media \n Publications \n Login \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCGWBPublications and Media Warehouse\n\n\n\n\n\n\nMedia\n\n\nPublication\n\n\n\n\n\n\n\n\n\n\n\nChoose Category\nAnnual Action Plan\nAnnual Reports\nAquifer Atlas and Maps\nAquifer Mapping\nArtificial Recharge\nAzadi Ka Amrit Mahotsav\nAzadi Ka Amrit Mahotsav\nBhu-jal News\nBhujal Samvad\nCGWA\nGround Water Exploration\nGround Water Level\nGround Water Quality\nGroundwater Modeling\nLiFE Mission\nNews Paper Cuttings\nPilot Aquifer Mapping\nPolicy Documents\nR and D Reports\nResource Assessment\nSharing of 
# ...
